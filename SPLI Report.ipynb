# %%
from tkinter import *
from tkinter import filedialog as fd
from tkinter import messagebox

import io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings

from matplotlib.backends.backend_pdf import PdfPages

import webbrowser

def clicked1():
    
    filename= fd.askopenfilename()
    txt12.insert(0,filename)
def clicked2():
    #global filename1
    filename1 = fd.askopenfilename()
    txt13.insert(0,filename1)
def clicked3():
    #global filename2
    filename2= fd.askopenfilename()
    txt14.insert(0,filename2)

def clicked4():
#     for i in range(0,17):
#         chk="txt"+str(i)
#         if len(exec("%s",chk).get()) == 0:
#             messagebox.showerror("Filds not filled", "fill filds")
    if len(txt0.get()) == 0:
        messagebox.showerror("Filds not filled", "fill filds")    
#     elif len(txt1.get()) == 0:
#         messagebox.showerror("Filds not filled", "fill filds")    
#     elif len(txt2.get()) == 0:
#         messagebox.showerror("Filds not filled", "fill filds")
#     elif len(txt3.get()) == 0:
#         messagebox.showerror("Filds not filled", "fill filds")    
#     elif len(txt4.get()) == 0:
#         messagebox.showerror("Filds not filled", "fill filds")           
#     elif len(txt5.get()) == 0:
#         messagebox.showerror("Filds not filled", "fill filds")    
#     elif len(txt6.get()) == 0:
#         messagebox.showerror("Filds not filled", "fill filds")
#     elif len(txt7.get()) == 0:
#         messagebox.showerror("Filds not filled", "fill filds")    
#     elif len(txt8.get()) == 0:
#         messagebox.showerror("Filds not filled", "fill filds") 
#     elif len(txt9.get()) == 0:
#         messagebox.showerror("Filds not filled", "fill filds")    
#     elif len(txt10.get()) == 0:
#         messagebox.showerror("Filds not filled", "fill filds")
#     elif len(txt11.get()) == 0:
#         messagebox.showerror("Filds not filled", "fill filds")    
    elif len(txt12.get()) == 0:
        messagebox.showerror("Filds not filled", "fill filds")
    elif len(txt13.get()) == 0:
        messagebox.showerror("Filds not filled", "fill filds")
    elif len(txt14.get()) == 0:
        messagebox.showerror("Filds not filled", "fill filds")

    else:
        df=dataget1()
        list1=dataget2()
        list2=dataget3()
        webview(list1[0],list1[1],list2[0],df)
    #print(txt12.get())

def dataget2():
   # loading company paramiter
    file1=txt13.get().replace('/' ,'\\')
    xls_file1 = pd.ExcelFile(file1)
    df20 = xls_file1.parse()
    df20=df20.fillna(0)
    df20=df20.round({'GP Margin(%)': 1, 'Project Invoice': 2,'Projest Cost':2,'Total Tax':2,'Taxes':2,'Workers Comp':2,'Wages':2,'Total Hour':2,'Average Hours':2,'Admin Fees + Others':2})
    str_io = io.StringIO()

    df20.to_html(buf=str_io, classes='table table-striped',index=False)

    html_str3 = str_io.getvalue()
    
    #df20
    df23=df20.head(len(df20.index)-1)
    df23=df23[['Projects','People','Average Hours','Total Hour','GP Margin(%)']]
    df23=df23.fillna(0)

    str_io = io.StringIO()

    df23.to_html(buf=str_io, classes='table table-striped',index=False)

    html_str = str_io.getvalue()
    #df23
    
    #short value by Average Hours
    df21=df20.head(len(df20.index)-1)
    df21=df21.sort_values('Average Hours')
    df21=df21.reset_index(drop=True)
    df21
    #Bar graph Avarage Working Hour vs Projects
    x = df21['Projects']
    y = df21['Average Hours']
    z = df21['People']
    fig, ax = plt.subplots(figsize=(20,15))    
    width = 0.75 # the width of the bars 
    ind = np.arange(len(y))  # the x locations for the groups
    ax.barh(ind, y, width,)
    ax.set_yticks(ind+width/2-.3)
    ax.set_yticklabels(x, minor=False)
    plt.title('Avarage Working Hour vs Projects',fontsize=20)
    plt.xlabel('Avarage Working Hour',fontsize=20)
    plt.ylabel('Projects',fontsize=20)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.xlim(0,50)
    j=0
    for i, v in enumerate(y):
        ax.text(v/2-1 , i-.1 , str(z[j])+' people', color='white', fontweight='bold',fontsize=15)
        j=j+1
    plt.savefig('images/awhvspj.png',bbox_inches = 'tight')
    
    #short value by Average Hours
    df22=df20.head(len(df20.index)-1)
    df22=df22.sort_values('GP Margin(%)')
    df22=df22.reset_index(drop=True)
    df22=df22.round({'GP Margin(%)': 1, 'Project Invoice': 2,'Projest Cost':2,'Total Tax':2,'Taxes':2,'Workers Comp':2,'Wages':2,'Total Hour':2,'Average Hours':2,'Admin Fees + Others':2})
    df22
    
    #Bar Graph Profitability vs Projects
    x = df22['Projects']
    y = df22['GP Margin(%)']
    z = df22['People']
    fig, ax = plt.subplots(figsize=(20,15))    
    width = 0.75 # the width of the bars 
    ind = np.arange(len(y))  # the x locations for the groups
    ax.barh(ind, y, width,color='seagreen')
    ax.set_yticks(ind+width/2-.3)
    ax.set_yticklabels(x, minor=False)
    plt.title('Profitability vs Projects',fontsize=20)
    plt.xlabel('Profitability',fontsize=20)
    plt.ylabel('Projects',fontsize=20)
    #plt.xlim(0,100,10)
    plt.xticks(np.arange(-10,110,10),fontsize=20)
    plt.yticks(fontsize=20)
    #plt.xlim(0,50)
    j=0
    for i, v in enumerate(y):
        ax.text(v/2-1 , i-.1 , str(z[j])+' people', color='white', fontweight='bold',fontsize=15)
        j=j+1

    plt.savefig('images/profvspj.png',bbox_inches = 'tight')
    
    return [html_str,html_str3]

def dataget1():
    file1=txt12.get().replace('/' ,'\\')
    # loading week vs hours
    
    xls_file1 = pd.ExcelFile(file1)
    df15 = xls_file1.parse()
   
    
    #custom bar graph Efficiency of workers per week

    x = df15.tail(6)['Week']
    popularity = df15.tail(6)['Efficiency']
    x_pos = [i for i, _ in enumerate(x)]

    fig, ax = plt.subplots(figsize=(20,10))
    rects1 = ax.bar(x_pos, popularity,color='orange')
    #plt.yticks(0,100,1)
    plt.ylim(0,100)
    plt.xlabel("Time",fontsize=20)
    plt.ylabel("Percentage",fontsize=20)
    plt.title("Efficiency of workers per week",fontsize=20)
    plt.xticks(x_pos, x)
    # Turn on the grid
    #plt.minorticks_on()
    #plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
    # Customize the minor grid
    #plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
    def autolabel(rects):
        """
        Attach a text label above each bar displaying its height
        """
        for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                    '%.2f' % float(height)+"%",
            ha='center', va='bottom',fontsize=20)
    autolabel(rects1)
    plt.yticks(fontsize=20)
    plt.xticks(fontsize=20)
    plt.savefig('images/effivswk.png')
    plt.show()
    
    #custom bar graph GP Margin(%) per week


    x = df15.tail(4)['Week']
    popularity = df15.tail(4)['GP Margin(%)']
    x_pos = [i for i, _ in enumerate(x)]

    fig, ax = plt.subplots(figsize=(20,10))
    rects1 = ax.bar(x_pos, popularity,color='#58508d')
    #plt.yticks(0,100,1)
    #plt.ylim(0,100,10)
    plt.yticks(np.arange(0,100,10))
    plt.xlabel("Time",fontsize=20)
    plt.ylabel("Percentage",fontsize=20)
    plt.title("GP Margin(%) per week",fontsize=20)
    plt.xticks(x_pos, x)
    # Turn on the grid
    #plt.minorticks_on()
    #plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
    # Customize the minor grid
    #plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
    def autolabel(rects):
        """
        Attach a text label above each bar displaying its height
        """
        for rect in rects:
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                    '%.2f' % float(height)+"%",
            ha='center', va='bottom',fontsize=20)
    autolabel(rects1)
    plt.yticks(fontsize=20)
    plt.xticks(fontsize=20)
    plt.savefig('images/gpvswk.png')
    plt.show()
    
    #custom line graph Total Working hour per week
    
    ax=df15.tail(6).plot(x="Week", y="Total Hours",kind='line',marker='o',ylim=(0,1500),figsize=(15,5))
    ax.locator_params(integer=True)
    plt.title('Total Working hour per week',fontsize=20)
    plt.grid(True)
    plt.xlabel("Week",fontsize=20)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=15)
    plt.savefig('images/thvswk.png',bbox_inches = 'tight')

    #custom line graph Average Working hour per week

    ax=df15.tail(6).plot(x="Week", y="Average Hours",kind='line',marker='*',color='c',ylim=(0,40),figsize=(15,5))
    ax.locator_params(integer=True)
    plt.title('Average Working hour per week',fontsize=20)
    plt.grid(True)
    plt.xlabel("Week",fontsize=20)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=15)
    plt.savefig('images/ahvswk.png',bbox_inches = 'tight')
    
    return df15
    
def dataget3():
    # loading splireport
    
    file3=txt14.get().replace('/' ,'\\')
    xls_file1 = pd.ExcelFile(file3)
    df19 = xls_file1.parse()
    df19=df19.fillna(0)
    # df19=df19.rename(columns = {"Employee Name": "People", 
    #                                   "GP Margin":"Profitability"})
    # df18=df18.drop(['Workers Comp','Taxes','Total Tax','Project Cost','Project Invoice','Total profit'], axis=1)
    str_io = io.StringIO()

    df19[['Project name','Employee Name','Normal Hour','OT Hour','D.OT','Total Hour','Pay rate']].to_html(buf=str_io, classes='table table-striped',index=False)

    html_str2 = str_io.getvalue()
    return [html_str2]
    #df19[['Project name','Employee Name','Normal Hour','OT Hour','D.OT','Total Hour','Pay rate']]

#def 
    

def  webview(html_str,html_str3,html_str2,df15):
    
    f = open('helloworld.html','w')

    message = """<!doctype html>
    <html>
    <head>
    <meta charset="utf-8">
    <title>Reports</title>
    <link href="https://cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/3.3.7/css/bootstrap.css" rel="stylesheet">


    <link href="https://fonts.googleapis.com/css?family=Lato&display=swap" rel="stylesheet">
    <style type="text/css">

    body{font-family: 'Lato', sans-serif; font-size:16px;}
    .noPad{padding-left:0; padding-right:0;}

    .dateSec{background-color:#fff; border-bottom: 1px solid rgba(0,0,0,.1); padding:10px 30px; text-align: center;}

    .dateSec h4 span{color:#9b9898; font-style:italic; font-weight:300}
    .fontW700{font-weight:700}

    .card {margin-bottom:20px}
        .card img{    width: 30px; margin-right: 20px; height: 100%;  vertical-align: bottom;}
    .card, .box { border-radius: 4px; background-color: #fff; border: 1px solid rgba(0,0,0,.1);}
    .card-stats .card-body { padding: 15px 15px 0;}
    .icon-warning {color: #ff9500; font-size:30px; margin-top: 20px;}
    .card .card-category, .card label { font-size: 18px;      color: #494949; }
    .card .card-category, .card .card-title{text-align: center;}
    .card .card-title {font-size:30px; font-weight:500;}
    .card .stats {color: #a9a9a9; padding: 10px;  font-size: 14px;     border-top: 1px solid #ccc;}
    .card .stats i{margin-right:10px;}
    .card .stats span{float:right; color:#454545;}
    hr{margin:0;}
    .centre {margin: 100px auto 30px auto; float: none;}
    .marginAuto{float:none; margin:0 auto; }

    .table{width:100%; margin: 20px auto 0 auto; border: 1px solid #ccc;}
    .red{color:#c41515}
    .table1{width:52%; margin:0 auto;}
    .table1,.table1>tbody>tr>td {border:none; margin-top:5px;}

    .operationSec{margin:60px auto}
    .operationSec h5{text-align:center; font-size:22px; margin-bottom:20px; font-weight:700;}
    .box{ margin-bottom:20px; display: flex; text-align: center;}
    .box h6{font-size:15px;}
    .box h4{font-size:20px; color:#000; font-weight:700; margin-top:15px}
    .box li{float:left; list-style-type:none; padding: 10px; width: 50%; border-right: 1px solid #ccc;}
    .box li:last-of-type{border-right:0}
    .img-responsive {margin:40px auto}
    .icon-big img{float:left; width: 100%;}
        .card-category p{margin-top:10px}

    @media screen and (max-width:991px){
        .card img { width:7%; margin-top: 20px;  float: left;}
    }
    </style>
    </head>

    <body>

    <section class="container-fluid noPad">
        <div class="col-lg-12 col-md-12 dateSec">
            <h4 class="fontW700" ><span>Week 42,</span> Oct 14th - Oct 19th, 2019 </h4>
        </div>
        <div class="col-lg-10 col-md-10 centre">
            <div class="col-lg-3 col-md-4 col-sm-3 col-xs-3">
        <div class="card card-stats">
        <div class="card-body">
        <div class="row">
        <div class="numbers"><div>
        <div class="card-category">
            <img src="https://image.flaticon.com/icons/svg/2140/2140920.svg">
            <p>Workers</p>
            </div> 
        <h4 class="card-title" id="nowk1">46</h4>
        </div>
        </div>
            <div class="stats"><div>Last Week
        <span id="nowk2">16 Workers</span>
        </div>
              </div>
        </div> 
        </div> 

              </div>
        </div>	
            <div class="col-lg-3 col-md-4 col-sm-3 col-xs-3">
        <div class="card card-stats">
        <div class="card-body">
        <div class="row">
        <div class="numbers"><div>
        <div class="card-category">
            <img src="https://image.flaticon.com/icons/svg/923/923477.svg"> 
            <p>Projects</p> 
            </div>
        <h4 class="card-title" id="proj1">16</h4>
        </div>
        </div>
        <div class="stats"><div>Last Week
        <span id="proj2">16 projects</span>
        </div>
              </div>
        </div> 
        </div> 

              </div>
        </div>
            <div class="col-lg-3 col-md-4 col-sm-3 col-xs-3">
        <div class="card card-stats">
        <div class="card-body">
        <div class="row">
        <div class="numbers"><div>
        <div class="card-category">
            <img src="https://image.flaticon.com/icons/svg/142/142078.svg"> 
            <p>Hours Worked</p> 
            </div>
        <h4 class="card-title" id="hour1">1176</h4>
        </div>
        </div>
            <div class="stats"><div>Last Week
        <span id="hour2">1160 Hours</span>
        </div>
              </div>
        </div> 
        </div> 

              </div>
        </div>
            <div class="col-lg-3 col-md-4 col-sm-3 col-xs-3">
        <div class="card card-stats">
        <div class="card-body">
        <div class="row">
        <div class="numbers"><div>
        <div class="card-category"><img src="https://image.flaticon.com/icons/svg/881/881930.svg">
            <p>Efficiency Rate</p> </div>
        <h4 class="card-title" id="rate1">65%</h4>
        </div>
        </div>
            <div class="stats"><div>Last Week
        <span id="rate2">54%</span>
        </div>
              </div>
        </div> 
        </div> 

              </div>
        </div>
        </div>
        <script>

    </script>
    </section>

    <div class="clearfix"></div>	
    <div class="col-lg-10 col-md-10 marginAuto">
        <img src="images/thvswk.png" class="img-responsive">
        <img src="images/ahvswk.png" class="img-responsive">
    </div>	
    <div class="col-lg-10 col-md-10 marginAuto">
    <table class="table table-hover table-striped">
    """+html_str+"""
    </table>
    </div>
    <div class="col-lg-10 col-md-10 marginAuto">
        <img src="images/awhvspj.png" class="img-responsive">
    </div>	
    <div class="col-lg-10 col-md-10 marginAuto">
        <img src="images/profvspj.png" class="img-responsive">
    </div>
    <div class="col-lg-10 col-md-10 marginAuto operationSec">

        <h5>Operations</h5>

        <ul class="box">
            <li>
            <h6>New Work orders</h6>
            <h4 id="order1">6</h4>	
            </li>
            <li>
            <h6>Open Work orders</h6>
            <h4 id="order2"></h4>	
            </li>
            <li>
            <h6>Cancelled / Lost Work Orders</h6>
            <h4 id="order3">3</h4>	
            </li>
            <li>
            <h6>Interviewed</h6>
            <h4 id="order4">26</h4>	
            </li><li>
            <h6>SPLI Applications</h6>
            <h4 id="order5">8</h4>	
            </li>
        </ul>

        <div class="col-lg-10 col-md-10 marginAuto">
        <img src="images/effivswk.png" class="img-responsive">
    </div>
    <table class="table table-hover table-striped">
    """+html_str2+"""
    </table>
    <table class="table table-hover table-striped">
    """+html_str3+"""
    </table>
    <section>


    <script>
    document.getElementById("nowk1").innerHTML = '"""+str(int(df15['Employees'][df15.index[-1]]))+"""'; <!-- Workers this week -->
    document.getElementById("proj1").innerHTML = '"""+str(int(df15['Project'][df15.index[-1]]))+"""';<!-- Project this week -->
    document.getElementById("hour1").innerHTML = '"""+str(df15['Total Hours'][df15.index[-1]])+"""';<!-- Hour Worked this week -->
    document.getElementById("rate1").innerHTML = '"""+str(df15['Efficiency'][df15.index[-1]])+"""%';<!-- Efficiency Rate this week -->

    document.getElementById("nowk2").innerHTML = '"""+str(int(df15['Employees'][df15.index[-2]]))+"""';<!-- Workers previous week -->
    document.getElementById("proj2").innerHTML = '"""+str(int(df15['Project'][df15.index[-2]]))+"""';<!-- Project previous week -->
    document.getElementById("hour2").innerHTML = '"""+str(df15['Total Hours'][df15.index[-2]])+"""';<!-- Hour Worked previous week -->
    document.getElementById("rate2").innerHTML = '"""+str(df15['Efficiency'][df15.index[-2]])+"""%';<!-- Efficiency Rate previous week -->

    document.getElementById("order1").innerHTML = '"""+str(int(df15['New Work Order'][df15.index[-1]]))+"""';<!-- New Work orders  -->
    document.getElementById("order2").innerHTML = '"""+str(int(df15['Open Work Order'][df15.index[-1]]))+"""';<!-- Open Work orders -->
    document.getElementById("order3").innerHTML = '"""+str(int(df15['cancle work order'][df15.index[-1]]))+"""';<!-- Cancelled / Lost Work Orders -->
    document.getElementById("order4").innerHTML = '"""+str(int(df15['Interviewed'][df15.index[-1]]))+"""';<!-- Interviewed -->
    document.getElementById("order5").innerHTML = '"""+str(int(df15['SPLI Applicants'][df15.index[-1]]))+"""';<!-- SPLI Applications -->
    </script>
    </body>
    </html>

    """

    f.write(message)
    f.close()

    webbrowser.open_new_tab('helloworld.html')

    
window = Tk()
x=0
screen_x  = window.winfo_screenwidth()
screen_y  = window.winfo_screenheight()
windows_x = 900
windows_y = 700
 
pos_x = (screen_x // 2) - (windows_x // 2)
pos_y = (screen_y // 2) - (windows_y // 2)
 
geo   = ("{}x{}+{}+{}").format(windows_x, windows_y, pos_x, pos_y)
window.wm_geometry(geo)
window.resizable(0,0)
window.title("Spli Report Genarator")
 
#window.geometry('500x750+ 400+300')

lbl15 = Label(window, text="Date from:")
lbl15.grid(column=0, row=0)
 
txt15 = Entry(window,width=10)
txt15.grid(column=1, row=0)

lbl16 = Label(window, text="Date to:")
lbl16.grid(column=2, row=0)
 
txt16 = Entry(window,width=10)
txt16.grid(column=3, row=0)

lbl17 = Label(window, text="Week no:")
lbl17.grid(column=0, row=1)
 
txt17 = Entry(window,width=10)
txt17.grid(column=1, row=1)

lbl = Label(window, text="This Week workers")
lbl.grid(column=0, row=2)
 
txt = Entry(window,width=10)
txt.grid(column=1, row=2)


# lbl = Label(window, text="This Week workers")
# lbl.grid(column=0, row=2)
 
# txt0 = Entry(window,width=10)
# txt0.grid(column=1, row=2)

# lbl1 = Label(window, text="This week project")
# lbl1.grid(column=0, row=3)
 
# txt1 = Entry(window,width=10)
# txt1.grid(column=1, row=3)

# lbl2 = Label(window, text="This week hours worked")
# lbl2.grid(column=0, row=4)

# txt2 = Entry(window,width=10)
# txt2.grid(column=1, row=4)

# lbl3 = Label(window, text="This week efficiency rate")
# lbl3.grid(column=0, row=5)
 
# txt3 = Entry(window,width=10)
# txt3.grid(column=1, row=5)

# lbl4 = Label(window, text="Previous Week workers")
# lbl4.grid(column=2, row=2)
 
# txt4 = Entry(window,width=10)
# txt4.grid(column=3, row=2)


# lbl5 = Label(window, text="Previous week project")
# lbl5.grid(column=2, row=3)
 
# txt5 = Entry(window,width=10)
# txt5.grid(column=3, row=3)

# lbl6 = Label(window, text="Previous week hours worked")
# lbl6.grid(column=2, row=4)
 
# txt6 = Entry(window,width=10)
# txt6.grid(column=3, row=4)

# lbl7 = Label(window, text="Previous week efficiency rate")
# lbl7.grid(column=2, row=5)
 
# txt7 = Entry(window,width=10)
# txt7.grid(column=3, row=5)

# lbl8 = Label(window, text="New Work orders")
# lbl8.grid(column=1, row=7)
 
# txt8 = Entry(window,width=10)
# txt8.grid(column=2, row=7)


# lbl9 = Label(window, text="Open Work orders")
# lbl9.grid(column=1, row=8)
 
# txt9 = Entry(window,width=10)
# txt9.grid(column=2, row=8)

# lbl10 = Label(window, text="Cancelled Work Orders")
# lbl10.grid(column=1, row=9)
 
# txt10 = Entry(window,width=10)
# txt10.grid(column=2, row=9)

# lbl11 = Label(window, text="Interviewed")
# lbl11.grid(column=1, row=10)
 
# txt11 = Entry(window,width=10)
# txt11.grid(column=2, row=10)

# lbl12 = Label(window, text="SPLI Applications")
# lbl12.grid(column=1, row=11)
 
# txt12 = Entry(window,width=10)
# txt12.grid(column=2, row=11)

lbl12 = Label(window, text="Weekly efficiency exel")
lbl12.grid(column=0, row=12)
 
txt12 = Entry(window,width=30)
txt12.grid(column=1, row=12)

btn = Button(window, text="Upload", command=clicked1)
btn.grid(column=2,row=12)

lbl13 = Label(window, text="Company Paramiter exel")
lbl13.grid(column=0, row=13)
 
txt13 = Entry(window,width=30)
txt13.grid(column=1, row=13)

btn2 = Button(window, text="Upload", command=clicked2)
btn2.grid(column=2,row=13)

lbl14 = Label(window, text="Spli Payroll exel")
lbl14.grid(column=0, row=14)
 
txt14 = Entry(window,width=30)
txt14.grid(column=1, row=14)

btn3 = Button(window, text="Upload", command=clicked3)
btn3.grid(column=2,row=14)

btn4 = Button(window, text="Generate Report", command=clicked4)
btn4.grid(column=1,row=16)
 
window.mainloop()
#type(txt14)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-179-c2309db07e4a> in <module>
#     557
#     558 lbl12 = Label(window, text="Weekly efficiency exel")
# --> 559 lbl12.grid(column=(0,1), row=12)
#     560
#     561 txt12 = Entry(window,width=30)
#
# ~\AppData\Local\Continuum\anaconda3\lib\tkinter\__init__.py in grid_configure(self, cnf, **kw)
#    2224         self.tk.call(
#    2225               ('grid', 'configure', self._w)
# -> 2226               + self._options(cnf, kw))
#    2227     grid = configure = config = grid_configure
#    2228     bbox = grid_bbox = Misc.grid_bbox
#
# TclError: bad column value "0 1": must be a non-negative integer

# %%
print (filename)

# %%
type(txt14)
# Out:
# tkinter.Entry

# %%
chk="txt12"
exec('chk',)

# %%
chk
# Out:
# 'txt12'

# %%
print(chk)
# Out:
# txt12
